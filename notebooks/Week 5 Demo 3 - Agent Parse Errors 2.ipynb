# %% [markdown]
# # Demo 3 - Agent Parse Erros with rule-based router
# Here we get the same exception as in Demo 2

# %%
import crew_orchestrator

# %%
test_query2 = "Plot a line chart of the monthly sales data."

# %%
response = crew_orchestrator.rule_based_router(test_query2)
print(f'==BEGIN==\n{response}\n==END==')
# Out:
# Database connection established!
# 2025-04-13 08:34:06,423 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-04-13 08:34:06,423 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-13 08:34:06,427 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-04-13 08:34:06,428 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-13 08:34:06,429 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-04-13 08:34:06,430 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-13 08:34:06,432 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-13 08:34:06,433 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `finquery`
# 2025-04-13 08:34:06,433 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-13 08:34:06,458 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-04-13 08:34:06,460 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-13 08:34:06,461 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `finquery`
# ...
