# %%
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
from langchain_openai import ChatOpenAI
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent, AgentType
import pandas as pd

import os

# %%
load_dotenv()
# Out:
# True

# %%
DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASS = os.getenv('DB_PASS')

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
# Step 1: Set up database connection with SQLAlchemy
def initialize_db_connection():
    """Initialize SQLAlchemy engine and session for MySQL database."""
    try:
        engine = create_engine(
            f"mysql+mysqlconnector://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}",
            echo=True, # Verbose logging for debugging
            pool_pre_ping=True # Ensure active connections
        )
        Session = sessionmaker(bind=engine)
        session = Session()
        print("Database connection established!")
        return engine, session
    except Exception as e:
        print(f"Failed to connect to database: {e}")
        return None, None

# Step 2: Configure LangChain SQLDatabase
def get_sql_database(engine):
    """Wrap SQLAlchemy engine in LangChain's SQLDatabase."""
    try:
        db = SQLDatabase(engine)
        print("LangChain SQLDatabase initialized!")
        return db
    except Exception as e:
        print(f"Failed to initialize SQLDatabase: {e}")
        return None

# Step 3: Initialize OpenAI LLM
def initialize_llm():
    """Set up OpenAI LLM with API key"""
    try:
        llm = ChatOpenAI(
            model="gpt-4o-mini", # Cost-effective model: adjust as needed
            api_key=OPENAI_API_KEY,
            temperature=0
        )
        print("OpenAI LLM initialized!")
        return llm
    except Exception as e:
        print(f"Failed to initialize LLM: {e}")
        return None

# Step 4: Create SQL Agent
def create_agent(db, llm):
    """Build SQL agent with LangChain toolkit."""
    try:
        toolkit = SQLDatabaseToolkit(db=db, llm=llm)
        agent = create_sql_agent(
            llm=llm,
            toolkit=toolkit,
            agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, # React-based reasoning
            verbose=True, # Show intermediate steps
        )
        print("SQL Agent created successfully!")
        return agent
    except Exception as e:
        print(f"Failed to create agent: {e}")
        return None

# Step 5: Process Query and Format Output
def run_query(agent, query):
    """Execute a natural language query and return formatted response."""
    try:
        response = agent.run(query)
        # Format raw SQL output into natural language
        if "No results found" in response:
            return f"Sorry, I couldn't find any data for : '{query}'."
        else:
            return f"Here's what I found for '{query}':\n{response}"
    except Exception as e:
        return f"Error processing query '{query}': {e}"

# %%
# Set up
engine, session = initialize_db_connection()
if engine and session:
    db = get_sql_database(engine)
    if db:
        llm = initialize_llm()
        if llm:
            agent = create_agent(db, llm)
# Out:
# Database connection established!
# 2025-03-27 13:13:54,400 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-03-27 13:13:54,400 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,403 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-03-27 13:13:54,404 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,405 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-03-27 13:13:54,406 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,407 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:13:54,408 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `finquery`
# 2025-03-27 13:13:54,408 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,426 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-27 13:13:54,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:13:54,428 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `finquery`
# 2025-03-27 13:13:54,429 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,441 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `accounting_transactions`
# 2025-03-27 13:13:54,442 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,446 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `financial_transactions`
# 2025-03-27 13:13:54,447 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-27 13:13:54,450 INFO sqlalchemy.engine.Engine ROLLBACK
# LangChain SQLDatabase initialized!
# OpenAI LLM initialized!
# SQL Agent created successfully!

# %%
query = "What is the largest amount in the financial_transactions table?"
result = run_query(agent, query)
print(result)
# Out:
# /var/folders/fl/jdrswfjx50v2304lpb3s4wxr0000gn/T/ipykernel_96155/2214542209.py:65: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = agent.run(query)
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the `financial_transactions` table to identify the relevant columns for my query.
# Action: sql_db_schema
# Action Input: "financial_transactions"  2025-03-27 13:14:00,712 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:00,713 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:00,714 INFO sqlalchemy.engine.Engine [generated in 0.00136s] {'param_1': 3}
# 2025-03-27 13:14:00,716 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */To find the largest amount in the `financial_transactions` table, I will write a query that selects the maximum value from the `amount` column. I will also limit the results to 10, although there should only be one maximum value.
#
# Action: sql_db_query_checker
# Action Input: "SELECT MAX(amount) AS largest_amount FROM financial_transactions LIMIT 10;"  ```sql
# SELECT MAX(amount) AS largest_amount FROM financial_transactions;
# ```The query is correct. Now I will execute it to find the largest amount in the `financial_transactions` table.
#
# Action: sql_db_query
# Action Input: "SELECT MAX(amount) AS largest_amount FROM financial_transactions;"  2025-03-27 13:14:06,246 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:06,247 INFO sqlalchemy.engine.Engine SELECT MAX(amount) AS largest_amount FROM financial_transactions;
# 2025-03-27 13:14:06,248 INFO sqlalchemy.engine.Engine [generated in 0.00063s] {}
# 2025-03-27 13:14:06,313 INFO sqlalchemy.engine.Engine COMMIT
# [(Decimal('10000.00'),)]I now know the final answer
# Final Answer: The largest amount in the financial_transactions table is 10000.00.
#
# > Finished chain.
# Here's what I found for 'What is the largest amount in the financial_transactions table?':
# The largest amount in the financial_transactions table is 10000.00.

# %%
query = "What is the smallest amount in the financial_transactions table?"
result = run_query(agent, query)
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI will now check the schema of the financial_transactions table to understand its structure and identify the relevant columns for my query.
# Action: sql_db_schema
# Action Input: "financial_transactions"  2025-03-27 13:14:22,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:22,480 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:22,481 INFO sqlalchemy.engine.Engine [cached since 21.77s ago] {'param_1': 3}
# 2025-03-27 13:14:22,483 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */To find the smallest amount in the financial_transactions table, I will query the `amount` column and use the `MIN()` function to get the smallest value. I will also limit the results to 10, although there should only be one minimum value.
#
# Action: sql_db_query_checker
# Action Input: "SELECT MIN(amount) AS smallest_amount FROM financial_transactions LIMIT 10;"  ```sql
# SELECT MIN(amount) AS smallest_amount FROM financial_transactions;
# ```The query is correct. I will now execute it to find the smallest amount in the financial_transactions table.
#
# Action: sql_db_query
# Action Input: "SELECT MIN(amount) AS smallest_amount FROM financial_transactions;"  2025-03-27 13:14:25,216 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:25,217 INFO sqlalchemy.engine.Engine SELECT MIN(amount) AS smallest_amount FROM financial_transactions;
# 2025-03-27 13:14:25,217 INFO sqlalchemy.engine.Engine [generated in 0.00114s] {}
# 2025-03-27 13:14:25,240 INFO sqlalchemy.engine.Engine COMMIT
# [(Decimal('1.29'),)]I now know the final answer.
# Final Answer: The smallest amount in the financial_transactions table is 1.29.
#
# > Finished chain.
# Here's what I found for 'What is the smallest amount in the financial_transactions table?':
# The smallest amount in the financial_transactions table is 1.29.

# %%
query = "What is the average amount in the financial_transactions table?"
result = run_query(agent, query)
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the `financial_transactions` table to identify the relevant columns for calculating the average amount.
# Action: sql_db_schema
# Action Input: "financial_transactions"  2025-03-27 13:14:32,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:32,469 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:32,469 INFO sqlalchemy.engine.Engine [cached since 31.76s ago] {'param_1': 3}
# 2025-03-27 13:14:32,471 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */To calculate the average amount in the `financial_transactions` table, I will write a query that selects the average of the `amount` column.
#
# Action: sql_db_query_checker
# Action Input: "SELECT AVG(amount) AS average_amount FROM financial_transactions"  ```sql
# SELECT AVG(amount) AS average_amount FROM financial_transactions;
# ```The query is correct. Now I will execute it to get the average amount from the `financial_transactions` table.
# Action: sql_db_query
# Action Input: "SELECT AVG(amount) AS average_amount FROM financial_transactions"  2025-03-27 13:14:49,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:49,224 INFO sqlalchemy.engine.Engine SELECT AVG(amount) AS average_amount FROM financial_transactions
# 2025-03-27 13:14:49,224 INFO sqlalchemy.engine.Engine [generated in 0.00102s] {}
# 2025-03-27 13:14:49,250 INFO sqlalchemy.engine.Engine COMMIT
# [(Decimal('5009.012768'),)]I now know the final answer
# Final Answer: The average amount in the financial_transactions table is approximately 5009.01.
#
# > Finished chain.
# Here's what I found for 'What is the average amount in the financial_transactions table?':
# The average amount in the financial_transactions table is approximately 5009.01.

# %%
query = "How much did customer 926 spend?"
result = run_query(agent, query)
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the relevant tables to find out where customer spending information is stored. Since "accounting_transactions" and "financial_transactions" are the only tables available, I will check their schemas to see which one contains customer spending data.
#
# Action: sql_db_schema
# Action Input: "accounting_transactions, financial_transactions"  2025-03-27 13:14:51,893 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:51,894 INFO sqlalchemy.engine.Engine SELECT accounting_transactions.`Transaction_ID`, accounting_transactions.`Date`, accounting_transactions.`Account_Number`, accounting_transactions.`Transaction_Type`, accounting_transactions.`Amount`, accounting_transactions.`Currency`, accounting_transactions.`Counterparty`, accounting_transactions.`Category`, accounting_transactions.`Payment_Method`, accounting_transactions.`Risk_Incident`, accounting_transactions.`Risk_Type`, accounting_transactions.`Incident_Severity`, accounting_transactions.`Error_Code`, accounting_transactions.`User_ID`, accounting_transactions.`System_Latency`, accounting_transactions.`Login_Frequency`, accounting_transactions.`Failed_Attempts`, accounting_transactions.`IP_Region`
# FROM accounting_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:51,895 INFO sqlalchemy.engine.Engine [generated in 0.00177s] {'param_1': 3}
# 2025-03-27 13:14:51,897 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-27 13:14:51,899 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:51,899 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:51,900 INFO sqlalchemy.engine.Engine [cached since 51.19s ago] {'param_1': 3}
# 2025-03-27 13:14:51,902 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE accounting_transactions (
# 	`Transaction_ID` VARCHAR(50) NOT NULL,
# 	`Date` DATE,
# 	`Account_Number` BIGINT,
# 	`Transaction_Type` VARCHAR(100),
# 	`Amount` DECIMAL(15, 2),
# 	`Currency` VARCHAR(10),
# 	`Counterparty` VARCHAR(255),
# 	`Category` VARCHAR(100),
# 	`Payment_Method` VARCHAR(50),
# 	`Risk_Incident` TINYINT,
# 	`Risk_Type` VARCHAR(100),
# 	`Incident_Severity` VARCHAR(10),
# 	`Error_Code` VARCHAR(50),
# 	`User_ID` VARCHAR(50),
# 	`System_Latency` DECIMAL(10, 4),
# 	`Login_Frequency` INTEGER,
# 	`Failed_Attempts` INTEGER,
# 	`IP_Region` VARCHAR(100),
# 	PRIMARY KEY (`Transaction_ID`)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from accounting_transactions table:
# Transaction_ID	Date	Account_Number	Transaction_Type	Amount	Currency	Counterparty	Category	Payment_Method	Risk_Incident	Risk_Type	Incident_Severity	Error_Code	User_ID	System_Latency	Login_Frequency	Failed_Attempts	IP_Region
# TXN00001	2024-08-18	250637	Refund	952.11	USD	Garcia-Gordon	Payroll	Cash	0	None	None	None	U001	299.2600	6	2	TH
# TXN00002	2024-11-26	122794	Debit	3293.29	USD	Heath, Pena and Buchanan	Payroll	Cash	1	Error	Low	E002	U233	248.6100	4	1	TW
# TXN00003	2024-04-30	152231	Debit	2849.97	USD	Pham PLC	Operations	Cash	0	None	None	None	U251	378.6100	6	2	BI
# */
#
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */The relevant table for customer spending information is "financial_transactions," which contains a column for customer_id and amount. I will now construct a query to find the total amount spent by customer 926.
#
# Action: sql_db_query_checker
# Action Input: "SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;"  ```sql
# SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;
# ```The query is syntactically correct. I will now execute it to find out how much customer 926 spent.
#
# Action: sql_db_query
# Action Input: "SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;"  2025-03-27 13:15:00,197 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:15:00,198 INFO sqlalchemy.engine.Engine SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;
# 2025-03-27 13:15:00,198 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {}
# 2025-03-27 13:15:00,221 INFO sqlalchemy.engine.Engine COMMIT
# [(Decimal('539370.56'),)]I now know the final answer.
# Final Answer: Customer 926 spent a total of $539,370.56.
#
# > Finished chain.
# Here's what I found for 'How much did customer 926 spend?':
# Customer 926 spent a total of $539,370.56.

# %%
query = "How much did customer 926 spend?"
result = run_query(agent, query)
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the relevant tables to find out where customer spending information is stored. Since "accounting_transactions" and "financial_transactions" are the only tables available, I will check their schemas to see which one contains customer spending data.
#
# Action: sql_db_schema
# Action Input: "accounting_transactions, financial_transactions"  2025-03-27 13:14:51,893 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:51,894 INFO sqlalchemy.engine.Engine SELECT accounting_transactions.`Transaction_ID`, accounting_transactions.`Date`, accounting_transactions.`Account_Number`, accounting_transactions.`Transaction_Type`, accounting_transactions.`Amount`, accounting_transactions.`Currency`, accounting_transactions.`Counterparty`, accounting_transactions.`Category`, accounting_transactions.`Payment_Method`, accounting_transactions.`Risk_Incident`, accounting_transactions.`Risk_Type`, accounting_transactions.`Incident_Severity`, accounting_transactions.`Error_Code`, accounting_transactions.`User_ID`, accounting_transactions.`System_Latency`, accounting_transactions.`Login_Frequency`, accounting_transactions.`Failed_Attempts`, accounting_transactions.`IP_Region`
# FROM accounting_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:51,895 INFO sqlalchemy.engine.Engine [generated in 0.00177s] {'param_1': 3}
# 2025-03-27 13:14:51,897 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-27 13:14:51,899 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:14:51,899 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:14:51,900 INFO sqlalchemy.engine.Engine [cached since 51.19s ago] {'param_1': 3}
# 2025-03-27 13:14:51,902 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE accounting_transactions (
# 	`Transaction_ID` VARCHAR(50) NOT NULL,
# 	`Date` DATE,
# 	`Account_Number` BIGINT,
# 	`Transaction_Type` VARCHAR(100),
# 	`Amount` DECIMAL(15, 2),
# 	`Currency` VARCHAR(10),
# 	`Counterparty` VARCHAR(255),
# 	`Category` VARCHAR(100),
# 	`Payment_Method` VARCHAR(50),
# 	`Risk_Incident` TINYINT,
# 	`Risk_Type` VARCHAR(100),
# 	`Incident_Severity` VARCHAR(10),
# 	`Error_Code` VARCHAR(50),
# 	`User_ID` VARCHAR(50),
# 	`System_Latency` DECIMAL(10, 4),
# 	`Login_Frequency` INTEGER,
# 	`Failed_Attempts` INTEGER,
# 	`IP_Region` VARCHAR(100),
# 	PRIMARY KEY (`Transaction_ID`)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from accounting_transactions table:
# Transaction_ID	Date	Account_Number	Transaction_Type	Amount	Currency	Counterparty	Category	Payment_Method	Risk_Incident	Risk_Type	Incident_Severity	Error_Code	User_ID	System_Latency	Login_Frequency	Failed_Attempts	IP_Region
# TXN00001	2024-08-18	250637	Refund	952.11	USD	Garcia-Gordon	Payroll	Cash	0	None	None	None	U001	299.2600	6	2	TH
# TXN00002	2024-11-26	122794	Debit	3293.29	USD	Heath, Pena and Buchanan	Payroll	Cash	1	Error	Low	E002	U233	248.6100	4	1	TW
# TXN00003	2024-04-30	152231	Debit	2849.97	USD	Pham PLC	Operations	Cash	0	None	None	None	U251	378.6100	6	2	BI
# */
#
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */The relevant table for customer spending information is "financial_transactions," which contains a column for customer_id and amount. I will now construct a query to find the total amount spent by customer 926.
#
# Action: sql_db_query_checker
# Action Input: "SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;"  ```sql
# SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;
# ```The query is syntactically correct. I will now execute it to find out how much customer 926 spent.
#
# Action: sql_db_query
# Action Input: "SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;"  2025-03-27 13:15:00,197 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:15:00,198 INFO sqlalchemy.engine.Engine SELECT SUM(amount) AS total_spent FROM financial_transactions WHERE customer_id = 926;
# 2025-03-27 13:15:00,198 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {}
# 2025-03-27 13:15:00,221 INFO sqlalchemy.engine.Engine COMMIT
# [(Decimal('539370.56'),)]I now know the final answer.
# Final Answer: Customer 926 spent a total of $539,370.56.
#
# > Finished chain.
# Here's what I found for 'How much did customer 926 spend?':
# Customer 926 spent a total of $539,370.56.

# %%
query = "Get monthly sales data"
result = run_query(agent, query)
print('-------')
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the relevant tables to find out which one contains the monthly sales data. Since "accounting_transactions" and "financial_transactions" could both potentially have sales data, I will check their schemas.
#
# Action: sql_db_schema
# Action Input: "accounting_transactions, financial_transactions"  2025-03-27 13:17:45,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:17:45,130 INFO sqlalchemy.engine.Engine SELECT accounting_transactions.`Transaction_ID`, accounting_transactions.`Date`, accounting_transactions.`Account_Number`, accounting_transactions.`Transaction_Type`, accounting_transactions.`Amount`, accounting_transactions.`Currency`, accounting_transactions.`Counterparty`, accounting_transactions.`Category`, accounting_transactions.`Payment_Method`, accounting_transactions.`Risk_Incident`, accounting_transactions.`Risk_Type`, accounting_transactions.`Incident_Severity`, accounting_transactions.`Error_Code`, accounting_transactions.`User_ID`, accounting_transactions.`System_Latency`, accounting_transactions.`Login_Frequency`, accounting_transactions.`Failed_Attempts`, accounting_transactions.`IP_Region`
# FROM accounting_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:17:45,130 INFO sqlalchemy.engine.Engine [cached since 173.2s ago] {'param_1': 3}
# 2025-03-27 13:17:45,133 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-27 13:17:45,134 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:17:45,135 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:17:45,135 INFO sqlalchemy.engine.Engine [cached since 224.4s ago] {'param_1': 3}
# 2025-03-27 13:17:45,136 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE accounting_transactions (
# 	`Transaction_ID` VARCHAR(50) NOT NULL,
# 	`Date` DATE,
# 	`Account_Number` BIGINT,
# 	`Transaction_Type` VARCHAR(100),
# 	`Amount` DECIMAL(15, 2),
# 	`Currency` VARCHAR(10),
# 	`Counterparty` VARCHAR(255),
# 	`Category` VARCHAR(100),
# 	`Payment_Method` VARCHAR(50),
# 	`Risk_Incident` TINYINT,
# 	`Risk_Type` VARCHAR(100),
# 	`Incident_Severity` VARCHAR(10),
# 	`Error_Code` VARCHAR(50),
# 	`User_ID` VARCHAR(50),
# 	`System_Latency` DECIMAL(10, 4),
# 	`Login_Frequency` INTEGER,
# 	`Failed_Attempts` INTEGER,
# 	`IP_Region` VARCHAR(100),
# 	PRIMARY KEY (`Transaction_ID`)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from accounting_transactions table:
# Transaction_ID	Date	Account_Number	Transaction_Type	Amount	Currency	Counterparty	Category	Payment_Method	Risk_Incident	Risk_Type	Incident_Severity	Error_Code	User_ID	System_Latency	Login_Frequency	Failed_Attempts	IP_Region
# TXN00001	2024-08-18	250637	Refund	952.11	USD	Garcia-Gordon	Payroll	Cash	0	None	None	None	U001	299.2600	6	2	TH
# TXN00002	2024-11-26	122794	Debit	3293.29	USD	Heath, Pena and Buchanan	Payroll	Cash	1	Error	Low	E002	U233	248.6100	4	1	TW
# TXN00003	2024-04-30	152231	Debit	2849.97	USD	Pham PLC	Operations	Cash	0	None	None	None	U251	378.6100	6	2	BI
# */
#
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */The "accounting_transactions" table contains a "Date" and "Amount" column, which can be used to extract monthly sales data. The "financial_transactions" table also has a "date" and "amount" column, but it seems to focus more on customer transactions rather than sales. I will query the "accounting_transactions" table to get the monthly sales data.
#
# I will group the results by month and year, summing the amounts for each month.
#
# Action: sql_db_query_checker
# Action Input: "SELECT DATE_FORMAT(Date, '%Y-%m') AS Month, SUM(Amount) AS Total_Sales FROM accounting_transactions GROUP BY Month ORDER BY Month DESC LIMIT 10;"  ```sql
# SELECT DATE_FORMAT(Date, '%Y-%m') AS Month, SUM(Amount) AS Total_Sales FROM accounting_transactions GROUP BY Month ORDER BY Month DESC LIMIT 10;
# ```The query is syntactically correct. Now I will execute it to retrieve the monthly sales data.
#
# Action: sql_db_query
# Action Input: "SELECT DATE_FORMAT(Date, '%Y-%m') AS Month, SUM(Amount) AS Total_Sales FROM accounting_transactions GROUP BY Month ORDER BY Month DESC LIMIT 10;"  2025-03-27 13:17:50,513 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:17:50,514 INFO sqlalchemy.engine.Engine SELECT DATE_FORMAT(Date, '%Y-%m') AS Month, SUM(Amount) AS Total_Sales FROM accounting_transactions GROUP BY Month ORDER BY Month DESC LIMIT 10;
# 2025-03-27 13:17:50,514 INFO sqlalchemy.engine.Engine [generated in 0.00095s] {}
# 2025-03-27 13:17:50,533 INFO sqlalchemy.engine.Engine COMMIT
# [('2025-01', Decimal('895305.04')), ('2024-12', Decimal('4194356.36')), ('2024-11', Decimal('4207306.34')), ('2024-10', Decimal('4464840.94')), ('2024-09', Decimal('4024796.61')), ('2024-08', Decimal('4266347.18')), ('2024-07', Decimal('4276058.99')), ('2024-06', Decimal('3830612.42')), ('2024-05', Decimal('4150294.41')), ('2024-04', Decimal('4279452.31'))]I now know the final answer. The monthly sales data from the accounting transactions is as follows:
#
# - January 2025: $895,305.04
# - December 2024: $4,194,356.36
# - November 2024: $4,207,306.34
# - October 2024: $4,464,840.94
# - September 2024: $4,024,796.61
# - August 2024: $4,266,347.18
# - July 2024: $4,276,058.99
# - June 2024: $3,830,612.42
# - May 2024: $4,150,294.41
# - April 2024: $4,279,452.31
#
# Final Answer: The monthly sales data is as follows:
# - 2025-01: $895,305.04
# - 2024-12: $4,194,356.36
# - 2024-11: $4,207,306.34
# - 2024-10: $4,464,840.94
# - 2024-09: $4,024,796.61
# - 2024-08: $4,266,347.18
# - 2024-07: $4,276,058.99
# - 2024-06: $3,830,612.42
# - 2024-05: $4,150,294.41
# - 2024-04: $4,279,452.31
#
# > Finished chain.
# -------
# Here's what I found for 'Get monthly sales data':
# The monthly sales data is as follows:
# - 2025-01: $895,305.04
# - 2024-12: $4,194,356.36
# - 2024-11: $4,207,306.34
# - 2024-10: $4,464,840.94
# - 2024-09: $4,024,796.61
# - 2024-08: $4,266,347.18
# - 2024-07: $4,276,058.99
# - 2024-06: $3,830,612.42
# - 2024-05: $4,150,294.41
# - 2024-04: $4,279,452.31

# %%
query = """
Show me a line chart of the monthly sales data.
Write only the Python code using plotly to create this chart.  Use pandas to load data.
"""
result = run_query(agent, query)
print('-------')
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI should check the schema of the tables related to transactions to find the relevant columns for sales data. Since "accounting_transactions" and "financial_transactions" are the only tables, I will query their schemas.
# Action: sql_db_schema
# Action Input: "accounting_transactions, financial_transactions"  2025-03-27 13:19:40,177 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:19:40,177 INFO sqlalchemy.engine.Engine SELECT accounting_transactions.`Transaction_ID`, accounting_transactions.`Date`, accounting_transactions.`Account_Number`, accounting_transactions.`Transaction_Type`, accounting_transactions.`Amount`, accounting_transactions.`Currency`, accounting_transactions.`Counterparty`, accounting_transactions.`Category`, accounting_transactions.`Payment_Method`, accounting_transactions.`Risk_Incident`, accounting_transactions.`Risk_Type`, accounting_transactions.`Incident_Severity`, accounting_transactions.`Error_Code`, accounting_transactions.`User_ID`, accounting_transactions.`System_Latency`, accounting_transactions.`Login_Frequency`, accounting_transactions.`Failed_Attempts`, accounting_transactions.`IP_Region`
# FROM accounting_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:19:40,178 INFO sqlalchemy.engine.Engine [cached since 288.3s ago] {'param_1': 3}
# 2025-03-27 13:19:40,180 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-27 13:19:40,182 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:19:40,182 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:19:40,182 INFO sqlalchemy.engine.Engine [cached since 339.5s ago] {'param_1': 3}
# 2025-03-27 13:19:40,184 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE accounting_transactions (
# 	`Transaction_ID` VARCHAR(50) NOT NULL,
# 	`Date` DATE,
# 	`Account_Number` BIGINT,
# 	`Transaction_Type` VARCHAR(100),
# 	`Amount` DECIMAL(15, 2),
# 	`Currency` VARCHAR(10),
# 	`Counterparty` VARCHAR(255),
# 	`Category` VARCHAR(100),
# 	`Payment_Method` VARCHAR(50),
# 	`Risk_Incident` TINYINT,
# 	`Risk_Type` VARCHAR(100),
# 	`Incident_Severity` VARCHAR(10),
# 	`Error_Code` VARCHAR(50),
# 	`User_ID` VARCHAR(50),
# 	`System_Latency` DECIMAL(10, 4),
# 	`Login_Frequency` INTEGER,
# 	`Failed_Attempts` INTEGER,
# 	`IP_Region` VARCHAR(100),
# 	PRIMARY KEY (`Transaction_ID`)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from accounting_transactions table:
# Transaction_ID	Date	Account_Number	Transaction_Type	Amount	Currency	Counterparty	Category	Payment_Method	Risk_Incident	Risk_Type	Incident_Severity	Error_Code	User_ID	System_Latency	Login_Frequency	Failed_Attempts	IP_Region
# TXN00001	2024-08-18	250637	Refund	952.11	USD	Garcia-Gordon	Payroll	Cash	0	None	None	None	U001	299.2600	6	2	TH
# TXN00002	2024-11-26	122794	Debit	3293.29	USD	Heath, Pena and Buchanan	Payroll	Cash	1	Error	Low	E002	U233	248.6100	4	1	TW
# TXN00003	2024-04-30	152231	Debit	2849.97	USD	Pham PLC	Operations	Cash	0	None	None	None	U251	378.6100	6	2	BI
# */
#
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */To create a line chart of the monthly sales data, I need to query the relevant sales data from the `accounting_transactions` and `financial_transactions` tables. The relevant columns for sales data appear to be the `Date` and `Amount` from both tables.
#
# I will first query the `financial_transactions` table to get the monthly sales data, as it seems more directly related to sales transactions. I will group the data by month and sum the amounts.
#
# I will construct the query to get the total sales amount per month from the `financial_transactions` table.
#
# Action: sql_db_query_checker
# Action Input: "SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;"  ```sql
# SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;
# ```The query is syntactically correct. Now I will execute the query to retrieve the monthly sales data.
#
# Action: sql_db_query
# Action Input: "SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;"  2025-03-27 13:19:46,209 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:19:46,210 INFO sqlalchemy.engine.Engine SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;
# 2025-03-27 13:19:46,211 INFO sqlalchemy.engine.Engine [generated in 0.00112s] {}
# 2025-03-27 13:19:46,285 INFO sqlalchemy.engine.Engine COMMIT
# [('2018-03', Decimal('1411092.04')), ('2018-04', Decimal('8165918.47')), ('2018-05', Decimal('8757920.69')), ('2018-06', Decimal('8229321.90')), ('2018-07', Decimal('8717899.94')), ('2018-08', Decimal('8658032.26')), ('2018-09', Decimal('8395163.23')), ('2018-10', Decimal('8296004.70')), ('2018-11', Decimal('8226845.34')), ('2018-12', Decimal('8355343.64'))]I now know the final answer. The monthly sales data from the `financial_transactions` table is as follows:
#
# - March 2018: $1,411,092.04
# - April 2018: $8,165,918.47
# - May 2018: $8,757,920.69
# - June 2018: $8,229,321.90
# - July 2018: $8,717,899.94
# - August 2018: $8,658,032.26
# - September 2018: $8,395,163.23
# - October 2018: $8,296,004.70
# - November 2018: $8,226,845.34
# - December 2018: $8,355,343.64
#
# Final Answer: The monthly sales data is as follows:
# - March 2018: $1,411,092.04
# - April 2018: $8,165,918.47
# - May 2018: $8,757,920.69
# - June 2018: $8,229,321.90
# - July 2018: $8,717,899.94
# - August 2018: $8,658,032.26
# - September 2018: $8,395,163.23
# - October 2018: $8,296,004.70
# - November 2018: $8,226,845.34
# - December 2018: $8,355,343.64
#
# > Finished chain.
# -------
# Here's what I found for '
# Show me a line chart of the monthly sales data.
# Write only the Python code using plotly to create this chart.  Use pandas to load data.
# ':
# The monthly sales data is as follows:
# - March 2018: $1,411,092.04
# - April 2018: $8,165,918.47
# - May 2018: $8,757,920.69
# - June 2018: $8,229,321.90
# - July 2018: $8,717,899.94
# - August 2018: $8,658,032.26
# - September 2018: $8,395,163.23
# - October 2018: $8,296,004.70
# - November 2018: $8,226,845.34
# - December 2018: $8,355,343.64

# %%
query = """
Give me a line chart of the monthly sales data.
Write only the sql code to create this chart.
"""
result = run_query(agent, query)
print('-------')
print(result)
# Out:
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  accounting_transactions, financial_transactionsI need to check the schema of the relevant tables to find the columns that contain sales data. I will start with the `accounting_transactions` table.
# Action: sql_db_schema
# Action Input: "accounting_transactions"  2025-03-27 13:24:21,546 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:24:21,548 INFO sqlalchemy.engine.Engine SELECT accounting_transactions.`Transaction_ID`, accounting_transactions.`Date`, accounting_transactions.`Account_Number`, accounting_transactions.`Transaction_Type`, accounting_transactions.`Amount`, accounting_transactions.`Currency`, accounting_transactions.`Counterparty`, accounting_transactions.`Category`, accounting_transactions.`Payment_Method`, accounting_transactions.`Risk_Incident`, accounting_transactions.`Risk_Type`, accounting_transactions.`Incident_Severity`, accounting_transactions.`Error_Code`, accounting_transactions.`User_ID`, accounting_transactions.`System_Latency`, accounting_transactions.`Login_Frequency`, accounting_transactions.`Failed_Attempts`, accounting_transactions.`IP_Region`
# FROM accounting_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:24:21,548 INFO sqlalchemy.engine.Engine [cached since 569.7s ago] {'param_1': 3}
# 2025-03-27 13:24:21,551 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE accounting_transactions (
# 	`Transaction_ID` VARCHAR(50) NOT NULL,
# 	`Date` DATE,
# 	`Account_Number` BIGINT,
# 	`Transaction_Type` VARCHAR(100),
# 	`Amount` DECIMAL(15, 2),
# 	`Currency` VARCHAR(10),
# 	`Counterparty` VARCHAR(255),
# 	`Category` VARCHAR(100),
# 	`Payment_Method` VARCHAR(50),
# 	`Risk_Incident` TINYINT,
# 	`Risk_Type` VARCHAR(100),
# 	`Incident_Severity` VARCHAR(10),
# 	`Error_Code` VARCHAR(50),
# 	`User_ID` VARCHAR(50),
# 	`System_Latency` DECIMAL(10, 4),
# 	`Login_Frequency` INTEGER,
# 	`Failed_Attempts` INTEGER,
# 	`IP_Region` VARCHAR(100),
# 	PRIMARY KEY (`Transaction_ID`)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from accounting_transactions table:
# Transaction_ID	Date	Account_Number	Transaction_Type	Amount	Currency	Counterparty	Category	Payment_Method	Risk_Incident	Risk_Type	Incident_Severity	Error_Code	User_ID	System_Latency	Login_Frequency	Failed_Attempts	IP_Region
# TXN00001	2024-08-18	250637	Refund	952.11	USD	Garcia-Gordon	Payroll	Cash	0	None	None	None	U001	299.2600	6	2	TH
# TXN00002	2024-11-26	122794	Debit	3293.29	USD	Heath, Pena and Buchanan	Payroll	Cash	1	Error	Low	E002	U233	248.6100	4	1	TW
# TXN00003	2024-04-30	152231	Debit	2849.97	USD	Pham PLC	Operations	Cash	0	None	None	None	U251	378.6100	6	2	BI
# */I need to check the schema of the `financial_transactions` table as well to see if it contains any relevant sales data.
# Action: sql_db_schema
# Action Input: "financial_transactions"  2025-03-27 13:24:22,274 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:24:22,275 INFO sqlalchemy.engine.Engine SELECT financial_transactions.transaction_id, financial_transactions.date, financial_transactions.customer_id, financial_transactions.amount, financial_transactions.type, financial_transactions.description
# FROM financial_transactions
#  LIMIT %(param_1)s
# 2025-03-27 13:24:22,276 INFO sqlalchemy.engine.Engine [cached since 621.6s ago] {'param_1': 3}
# 2025-03-27 13:24:22,278 INFO sqlalchemy.engine.Engine ROLLBACK
#
# CREATE TABLE financial_transactions (
# 	transaction_id BIGINT NOT NULL,
# 	date DATE,
# 	customer_id BIGINT NOT NULL,
# 	amount DECIMAL(15, 2),
# 	type VARCHAR(10),
# 	description TEXT,
# 	PRIMARY KEY (transaction_id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from financial_transactions table:
# transaction_id	date	customer_id	amount	type	description
# 1	2020-10-26	926	6478.39	credit	Expect series shake art again our.
# 2	2020-01-08	466	1255.95	credit	Each left similar likely coach take.
# 3	2019-09-02	110	7969.68	debit	Direction wife job pull determine leader move college.
# */To create a line chart of the monthly sales data, I will query the `financial_transactions` table for the total sales amount grouped by month. The relevant columns are `date` and `amount`. I will format the date to extract the month and year for grouping.
#
# Action: sql_db_query_checker
# Action Input: "SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;"  ```sql
# SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;
# ```The query is syntactically correct. Now I will execute it to retrieve the monthly sales data.
#
# Action: sql_db_query
# Action Input: "SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;"  2025-03-27 13:24:25,842 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:24:25,844 INFO sqlalchemy.engine.Engine SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales FROM financial_transactions GROUP BY month ORDER BY month LIMIT 10;
# 2025-03-27 13:24:25,845 INFO sqlalchemy.engine.Engine [cached since 279.7s ago] {}
# 2025-03-27 13:24:25,921 INFO sqlalchemy.engine.Engine COMMIT
# [('2018-03', Decimal('1411092.04')), ('2018-04', Decimal('8165918.47')), ('2018-05', Decimal('8757920.69')), ('2018-06', Decimal('8229321.90')), ('2018-07', Decimal('8717899.94')), ('2018-08', Decimal('8658032.26')), ('2018-09', Decimal('8395163.23')), ('2018-10', Decimal('8296004.70')), ('2018-11', Decimal('8226845.34')), ('2018-12', Decimal('8355343.64'))]I now have the monthly sales data needed for the line chart. The results show the total sales amount for each month.
#
# Final Answer:
# ```sql
# SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales
# FROM financial_transactions
# GROUP BY month
# ORDER BY month
# LIMIT 10;
# ```
#
# > Finished chain.
# -------
# Here's what I found for '
# Give me a line chart of the monthly sales data.
# Write only the sql code to create this chart.
# ':
# ```sql
# SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales
# FROM financial_transactions
# GROUP BY month
# ORDER BY month
# LIMIT 10;
# ```

# %%
sql_query = """SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales 
FROM financial_transactions 
GROUP BY month 
ORDER BY month 
LIMIT 10;"""

# %%
with engine.connect() as connection:
    df = pd.read_sql(sql=text(sql_query), con=connection)
# Out:
# 2025-03-27 13:27:29,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-27 13:27:29,770 INFO sqlalchemy.engine.Engine SELECT DATE_FORMAT(date, '%Y-%m') AS month, SUM(amount) AS total_sales
# FROM financial_transactions
# GROUP BY month
# ORDER BY month
# LIMIT 10;
# 2025-03-27 13:27:29,771 INFO sqlalchemy.engine.Engine [generated in 0.00300s] {}
# 2025-03-27 13:27:29,867 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
df
# Out:
#      month  total_sales
# 0  2018-03   1411092.04
# 1  2018-04   8165918.47
# 2  2018-05   8757920.69
# 3  2018-06   8229321.90
# 4  2018-07   8717899.94
# 5  2018-08   8658032.26
# 6  2018-09   8395163.23
# 7  2018-10   8296004.70
# 8  2018-11   8226845.34
# 9  2018-12   8355343.64

# %%
df.head().to_markdown()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Data/code/finquery/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tabulate'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.head().to_markdown()
#
# File ~/Data/code/finquery/venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Data/code/finquery/venv/lib/python3.13/site-packages/pandas/core/frame.py:2983, in DataFrame.to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2981 kwargs.setdefault("tablefmt", "pipe")
#    2982 kwargs.setdefault("showindex", index)
# -> 2983 tabulate = import_optional_dependency("tabulate")
#    2984 result = tabulate.tabulate(self, **kwargs)
#    2985 if buf is None:
#
# File ~/Data/code/finquery/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.
